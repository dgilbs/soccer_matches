# %%
import pandas as pd
import numpy as np
import pymysql
import sqlite3
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 150)

# %%
connection = sqlite3.connect("/Users/danielgilberg/data_science/soccer_matches_project/database.sqlite")

# %%
c = connection.cursor()

# %%
match_query = '''SELECT * FROM match'''
match_df = pd.read_sql(match_query, connection)

# %%
country_query = '''SELECT * FROM country'''
country_df = pd.read_sql(country_query, connection)

# %%
league_query = '''SELECT * FROM league'''
league_df = pd.read_sql(league_query, connection)

# %%
team_query = '''SELECT * FROM team'''
team_df = pd.read_sql(team_query, connection)

# %%
player_query = '''SELECT * FROM player'''
player_df = pd.read_sql(player_query, connection)

# %%
player_atts_query = '''SELECT * FROM Player_Attributes'''
player_atts_df = pd.read_sql(player_atts_query, connection)

# %%
team_atts_query = '''SELECT * FROM team_attributes'''
team_atts_df = pd.read_sql(team_atts_query, connection)

# %%
class soccerData(object):
    def __init__(self, match_query, country_df, team_df, player_df, team_atts_df, player_atts_df, league_df):
        self.match_df = match_df
        self.country_df = country_df
        self.team_df = team_df
        self.teams = team_df.team_long_name.unique()
        self.player_df = player_df
        self.team_atts_df = team_atts_df
        self.player_atts_df = player_atts_df
        self.league_df = league_df
        
    def get_scores(self):
        home_team = temp.match_df[["id", "home_team_api_id", "home_team_goal"]]
        away_team = temp.match_df[["id", "away_team_api_id", "away_team_goal"]]
        teams = temp.team_df[["team_api_id", "team_long_name"]]
        home_df = pd.merge(home_team, teams,left_on="home_team_api_id", right_on="team_api_id")
        home_df.rename(columns={"team_long_name": "home_team"}, inplace=True)
        home_df.drop(["team_api_id", "home_team_api_id"], axis=1, inplace=True)
        away_df = pd.merge(away_team, teams,left_on="away_team_api_id", right_on="team_api_id")
        away_df.rename(columns={"team_long_name": "away_team"}, inplace=True)
        away_df.drop(["away_team_api_id", "team_api_id"], axis=1, inplace=True)
        df = pd.merge(home_df, away_df,on="id")
        df["Winner"] = df.apply(lambda row: self.get_winner(row["home_team_goal"],
                                                           row["home_team"], row["away_team_goal"],
                                                           row["away_team"]), axis=1)
        df["Result"] = df.apply(lambda row: self.get_home_result(row["home_team_goal"],
                                                           row["home_team"], row["away_team_goal"],
                                                           row["away_team"]), axis=1)
        other_info = self.match_df[["id", "country_id", "league_id", "season", "date"]]
        df = pd.merge(df, other_info, on="id")
        return df
    

    def get_winner(self, home_score, home_team, away_score, away_team):
        if home_score > away_score:
            return home_team
        elif away_score > home_score:
            return away_team
        else:
            return "Draw"
        
    def get_home_result(self, home_score, home_team, away_score, away_team):
        if home_score > away_score:
            return "Home"
        elif away_score > home_score:
            return "Away"
        else:
            return "Draw"
        
    def get_home_win_pct_by_season(self):
        df = self.get_scores()
        test = df[df.Result == "Home"]
        home_win_count = test.groupby(["country_id", "season"], as_index=False).agg({"date": len})
        home_win_count.rename(columns={"date": "home_wins"}, inplace=True)
        game_count = df.groupby(["country_id", "season"], as_index=False).agg({"date": len})
        game_count.rename(columns={"date": "total_games"}, inplace=True)
        final = pd.merge(game_count, home_win_count, on=["country_id", "season"])
        final["home_win_pct"] = final.apply(lambda row: round(row["home_wins"]/row["total_games"], 3), axis=1)
        final = self.country_df.merge(final, left_on="id", right_on="country_id")
        final.drop(["id", "country_id"], axis=1, inplace=True)
        return final
    
    def get_win_pct_by_team(self):
        df = self.get_scores()
        teams = self.team_df.team_long_name.unique()
        rows = list()
        for team in teams:
            mask = (df.home_team == team) | (df.away_team==team)
            games = len(df[mask])
            wins = len(df[df.Winner == team])
            pct = round(wins/games, 3)
            row = [team, pct]
            rows.append(row)

        df = pd.DataFrame(rows, columns=["Team", "Win_Pct"])
        return df
    
    def get_win_pct_by_team_and_season(self):
        df = self.get_scores()
        teams = self.team_df.team_long_name.unique()
        rows = list()
        for team in teams:
            mask = (df.home_team == team) | (df.away_team==team)
            test = df[mask]
            seasons = test.season.unique()
            for season in seasons: 
                temp_df = test[test.season == season]
                games = len(temp_df)
                wins = len(temp_df[temp_df.Winner == team])
                pct = round(wins/games, 3)
                row = [team, season, pct]
                rows.append(row)
        final = pd.DataFrame(rows, columns= ["Team", "Season", "Win_Pct"])
        return final
    
    def get_team_home_goal_differential_by_season(self):
        arr = temp.match_df.home_team_api_id.unique()
        rows = list()
        for team in arr:
            df = temp.match_df[temp.match_df.home_team_api_id == team]
            df = df.groupby("season", as_index=False).agg({"home_team_goal": np.sum, "away_team_goal": np.sum, "date":len})
            df.rename(columns={"home_team_goal": "home_goals_scored", "away_team_goal": "home_goals_conceded",
                              "date": "home_matches_played"}, inplace=True)
            seasons = list(df.season)
            goals_for = list(df.home_goals_scored)
            goals_against = list(df.home_goals_conceded)
            matches_played = list(df.home_matches_played)
            for i in range(0, len(seasons)):
                row = [team, seasons[i], goals_for[i], goals_against[i], matches_played[i]]
                rows.append(row)


        df = pd.DataFrame(rows, columns=["Team_ID", "Season", "Home_Goals_For", "Home_Goals_Against", "Home_Matches_Played"])



        teams = temp.team_df.copy()[["team_api_id", "team_long_name"]]

        final  = pd.merge(teams, df, left_on="team_api_id", right_on="Team_ID")
        final.drop("Team_ID", axis=1, inplace=True)
        final.rename(columns={"team_long_name": "Team"}, inplace=True)
        final["Home_GD"] = final.apply(lambda row: row["Home_Goals_For"]-row["Home_Goals_Against"], axis=1)
        return final
    
    def get_team_away_goal_differential_by_season(self):
        arr = temp.match_df.home_team_api_id.unique()
        rows = list()
        for team in arr:
            df = temp.match_df[temp.match_df.away_team_api_id == team]
            df = df.groupby("season", as_index=False).agg({"home_team_goal": np.sum, "away_team_goal": np.sum, "date":len})
            df.rename(columns={"away_team_goal": "away_goals_scored", "home_team_goal": "away_goals_conceded",
                              "date": "away_matches_played"}, inplace=True)
            seasons = list(df.season)
            goals_for = list(df.away_goals_scored)
            goals_against = list(df.away_goals_conceded)
            matches_played = list(df.away_matches_played)
            for i in range(0, len(seasons)):
                row = [team, seasons[i], goals_for[i], goals_against[i], matches_played[i]]
                rows.append(row)


        df = pd.DataFrame(rows, columns=["Team_ID", "Season", "Away_Goals_For", "Away_Goals_Against", "Away_Matches_Played"])



        teams = temp.team_df.copy()[["team_api_id", "team_long_name"]]

        final  = pd.merge(teams, df, left_on="team_api_id", right_on="Team_ID")
        final.drop("Team_ID", axis=1, inplace=True)
        final.rename(columns={"team_long_name": "Team"}, inplace=True)
        final["Away_GD"] = final.apply(lambda row: row["Away_Goals_For"]-row["Away_Goals_Against"], axis=1)
        return final
    
    def get_goal_diff_df_by_team_and_season(self):
        away = temp.get_team_away_goal_differential_by_season()
        home = temp.get_team_home_goal_differential_by_season()
        df = pd.merge(home, away, on=["team_api_id", "Team","Season"])
        df["Goals_For"] = df.apply(lambda row: row["Home_Goals_For"] + row["Away_Goals_For"], axis=1)
        df["Goals_Against"] = df.apply(lambda row: row["Home_Goals_Against"] + row["Away_Goals_Against"], axis=1)
        df["Goal_Differential"] = df.apply(lambda row: row["Goals_For"] - row["Goals_Against"],axis=1)
        df["Matches_Played"] = df.apply(lambda row: row["Home_Matches_Played"] + row["Away_Matches_Played"], axis=1)
        df["Home_Away_Diff"] = df.apply(lambda row: row["Home_GD"] - row["Away_GD"], axis=1)
        df.drop(["Home_Goals_For", "Home_Goals_Against", "Home_Matches_Played", "Away_Goals_For",
       "Away_Goals_Against", "Away_Matches_Played"], axis=1, inplace=True)
        leagues = self.get_team_leagues()
        df = pd.merge(df, leagues, on="Team")
        return df
    
    def get_team_leagues(self):
        df1 = self.match_df[["league_id", "home_team_api_id"]].drop_duplicates()
        df1.rename(columns={"home_team_api_id": "team_api_id"}, inplace=True)
        df2 = self.league_df[["id", "name"]]
        df2.rename(columns={"id": "league_id"}, inplace=True)
        df3 = self.team_df[["team_api_id", "team_long_name"]]
        df3.rename(columns={"team_long_name": "Team"}, inplace=True)
        final = pd.merge(df1, df2, on="league_id")
        final = pd.merge(final, df3, on="team_api_id")
        final.rename(columns={"name": "League"}, inplace=True)
        return final[["League", "Team"]]
        
        
        
    


temp = soccerData(match_df, country_df, team_df, player_df, team_atts_df, player_atts_df, league_df)

# %%
a = temp.get_team_leagues()
b = temp.get_goal_diff_df_by_team_and_season()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
b.groupby()
# Out:
#       team_api_id                     Team     Season  Home_GD  Away_GD  \
# 0            9987                 KRC Genk  2008/2009        2       -5
# 1            9987                 KRC Genk  2009/2010        3       -1
# 2            9987                 KRC Genk  2010/2011       22       15
# 3            9987                 KRC Genk  2011/2012       25       -9
# 4            9987                 KRC Genk  2012/2013       18        5
# 5            9987                 KRC Genk  2014/2015       13       -3
# 6            9987                 KRC Genk  2015/2016       16       -4
# 7            9993             Beerschot AC  2008/2009       13      -11
# 8            9993             Beerschot AC  2009/2010       -2      -11
# 9            9993             Beerschot AC  2010/2011        4      -20
# 10           9993             Beerschot AC  2011/2012       13      -19
# 11           9993             Beerschot AC  2012/2013      -14      -16
# 12          10000         SV Zulte-Waregem  2008/2009       16        3
# 13          10000         SV Zulte-Waregem  2009/2010       10       -3
# 14          10000         SV Zulte-Waregem  2010/2011        4       -6
# 15          10000         SV Zulte-Waregem  2011/2012        4      -10
# 16          10000         SV Zulte-Waregem  2012/2013        8       12
# 17          10000         SV Zulte-Waregem  2014/2015       -9       -4
# 18          10000         SV Zulte-Waregem  2015/2016        8       -7
# 19           9994         Sporting Lokeren  2008/2009        9       -1
# 20           9994         Sporting Lokeren  2009/2010       -7      -25
# 21           9994         Sporting Lokeren  2010/2011        8       -1
# 22           9994         Sporting Lokeren  2011/2012        6        2
# 23           9994         Sporting Lokeren  2012/2013        4       11
# 24           9994         Sporting Lokeren  2014/2015        9       -3
# 25           9994         Sporting Lokeren  2015/2016       -3       -2
# 26           9984        KSV Cercle Brugge  2008/2009        6      -11
# 27           9984        KSV Cercle Brugge  2009/2010        8       -3
# 28           9984        KSV Cercle Brugge  2010/2011        5       -6
# 29           9984        KSV Cercle Brugge  2011/2012        5       -6
# 30           9984        KSV Cercle Brugge  2012/2013      -11      -24
# 31           9984        KSV Cercle Brugge  2014/2015      -11      -13
# 32           8635           RSC Anderlecht  2008/2009       33       12
# 33           8635           RSC Anderlecht  2009/2010       17       25
# 34           8635           RSC Anderlecht  2010/2011       32        6
# 35           8635           RSC Anderlecht  2011/2012       31        4
# 36           8635           RSC Anderlecht  2012/2013       25       17
# 37           8635           RSC Anderlecht  2014/2015       14        7
# 38           8635           RSC Anderlecht  2015/2016       16        6
# 39           9991                 KAA Gent  2008/2009       16        9
# 40           9991                 KAA Gent  2009/2010        8       11
# 41           9991                 KAA Gent  2010/2011       12        5
# 42           9991                 KAA Gent  2011/2012       23        5
# 43           9991                 KAA Gent  2012/2013        0       -7
# 44           9991                 KAA Gent  2013/2014        4        1
# 45           9991                 KAA Gent  2014/2015       16        7
# 46           9991                 KAA Gent  2015/2016       21        6
# 47           9998                RAEC Mons  2008/2009       -2      -24
# 48           9998                RAEC Mons  2011/2012        9      -14
# 49           9998                RAEC Mons  2012/2013       -5        0
# 50           7947            FCV Dender EH  2008/2009       -2      -12
# 51           9985        Standard de Liège  2008/2009       30       10
# 52           9985        Standard de Liège  2009/2010        4        0
# 53           9985        Standard de Liège  2010/2011       18       -6
# 54           9985        Standard de Liège  2011/2012       19       -9
# 55           9985        Standard de Liège  2012/2013       13        8
# 56           9985        Standard de Liège  2014/2015        7        3
# 57           9985        Standard de Liège  2015/2016        6      -16
# 58           8203              KV Mechelen  2008/2009        4      -10
# 59           8203              KV Mechelen  2009/2010        3      -13
# 60           8203              KV Mechelen  2010/2011       14      -10
# 61           8203              KV Mechelen  2011/2012        2      -12
# 62           8203              KV Mechelen  2012/2013        1        1
# 63           8203              KV Mechelen  2014/2015       10      -12
# 64           8203              KV Mechelen  2015/2016        8      -10
# 65           8342           Club Brugge KV  2008/2009       14       -5
# 66           8342           Club Brugge KV  2009/2010       12        7
# 67           8342           Club Brugge KV  2010/2011       19        6
# 68           8342           Club Brugge KV  2011/2012       20       -1
# 69           8342           Club Brugge KV  2012/2013       16        7
# 70           8342           Club Brugge KV  2014/2015       26       15
# 71           8342           Club Brugge KV  2015/2016       33        1
# 72           9999            KSV Roeselare  2008/2009       -4      -22
# 73           9999            KSV Roeselare  2009/2010      -14      -15
# 74           8571              KV Kortrijk  2008/2009       -3      -15
# ...           ...                      ...        ...      ...      ...
# 1425         9956  Grasshopper Club Zürich  2013/2014       13       11
# 1426         9956  Grasshopper Club Zürich  2014/2015        3       -9
# 1427         9956  Grasshopper Club Zürich  2015/2016       14       -5
# 1428         6493            AC Bellinzona  2008/2009        6      -13
# 1429         6493            AC Bellinzona  2009/2010      -16      -34
# 1430         6493            AC Bellinzona  2010/2011      -13      -20
# 1431        10192           BSC Young Boys  2008/2009       33        6
# 1432        10192           BSC Young Boys  2009/2010       28        3
# 1433        10192           BSC Young Boys  2010/2011       12        3
# 1434        10192           BSC Young Boys  2011/2012       11        3
# 1435        10192           BSC Young Boys  2012/2013       15      -17
# 1436        10192           BSC Young Boys  2013/2014        7        2
# 1437        10192           BSC Young Boys  2014/2015       21       -2
# 1438        10192           BSC Young Boys  2015/2016       26        5
# 1439         9931                 FC Basel  2008/2009       24        4
# 1440         9931                 FC Basel  2009/2010       36        8
# 1441         9931                 FC Basel  2010/2011       23        9
# 1442         9931                 FC Basel  2011/2012       29       16
# 1443         9931                 FC Basel  2012/2013       26        4
# 1444         9931                 FC Basel  2013/2014       23       13
# 1445         9931                 FC Basel  2014/2015       28       15
# 1446         9931                 FC Basel  2015/2016       29       21
# 1447         9930                 FC Aarau  2008/2009        5      -21
# 1448         9930                 FC Aarau  2009/2010      -23      -33
# 1449         9930                 FC Aarau  2013/2014        1      -17
# 1450         9930                 FC Aarau  2014/2015      -13      -20
# 1451        10179                  FC Sion  2008/2009       -4      -12
# 1452        10179                  FC Sion  2009/2010       22      -16
# 1453        10179                  FC Sion  2010/2011        9        2
# 1454        10179                  FC Sion  2011/2012       -1        6
# 1455        10179                  FC Sion  2012/2013       -2      -12
# 1456        10179                  FC Sion  2013/2014       11      -18
# 1457        10179                  FC Sion  2014/2015        8       -9
# 1458        10179                  FC Sion  2015/2016       11       -8
# 1459        10199                FC Luzern  2008/2009        3      -20
# 1460        10199                FC Luzern  2009/2010       23      -12
# 1461        10199                FC Luzern  2010/2011        7       -2
# 1462        10199                FC Luzern  2011/2012       12        2
# 1463        10199                FC Luzern  2012/2013       -1      -10
# 1464        10199                FC Luzern  2013/2014        4      -10
# 1465        10199                FC Luzern  2014/2015        6        2
# 1466        10199                FC Luzern  2015/2016       13       -4
# 1467         9824                 FC Vaduz  2008/2009      -16      -41
# 1468         9824                 FC Vaduz  2014/2015      -16      -15
# 1469         9824                 FC Vaduz  2015/2016        0      -16
# 1470         7955          Neuchâtel Xamax  2008/2009        7      -14
# 1471         7955          Neuchâtel Xamax  2009/2010        8      -10
# 1472         7955          Neuchâtel Xamax  2010/2011      -12      -11
# 1473         7955          Neuchâtel Xamax  2011/2012        2       -2
# 1474        10243                FC Zürich  2008/2009       23       21
# 1475        10243                FC Zürich  2009/2010       11      -14
# 1476        10243                FC Zürich  2010/2011       20       10
# 1477        10243                FC Zürich  2011/2012        2       -3
# 1478        10243                FC Zürich  2012/2013       10        4
# 1479        10243                FC Zürich  2013/2014        4       -5
# 1480        10243                FC Zürich  2014/2015        2        5
# 1481        10243                FC Zürich  2015/2016       -3      -20
# 1482        10190            FC St. Gallen  2009/2010        1       -4
# 1483        10190            FC St. Gallen  2010/2011      -18      -15
# 1484        10190            FC St. Gallen  2012/2013       18        0
# 1485        10190            FC St. Gallen  2013/2014        4      -14
# 1486        10190            FC St. Gallen  2014/2015        8      -16
# 1487        10190            FC St. Gallen  2015/2016       -7      -18
# 1488        10191                  FC Thun  2010/2011        3        2
# 1489        10191                  FC Thun  2011/2012        6       -9
# 1490        10191                  FC Thun  2012/2013        7       -9
# 1491        10191                  FC Thun  2013/2014        8       -4
# 1492        10191                  FC Thun  2014/2015       14      -12
# 1493        10191                  FC Thun  2015/2016       -1       -8
# 1494         9777              Servette FC  2011/2012       -4       -4
# 1495         9777              Servette FC  2012/2013       -4      -26
# 1496         7730       FC Lausanne-Sports  2011/2012       -4      -28
# 1497         7730       FC Lausanne-Sports  2012/2013        1      -20
# 1498         7730       FC Lausanne-Sports  2013/2014      -15      -18
# 1499         7896                   Lugano  2015/2016       -6      -23
#
#       Goals_For  Goals_Against  Goal_Differential  Matches_Played  \
# 0            48             51                 -3              34
# 1            33             31                  2              28
# 2            64             27                 37              30
# 3            60             44                 16              30
# 4            63             40                 23              30
# 5            38             28                 10              30
# 6            42             30                 12              30
# 7            44             42                  2              34
# 8            30             43                -13              28
# 9            24             40                -16              30
# 10           45             51                 -6              30
# 11           31             61                -30              30
# 12           55             36                 19              34
# 13           39             32                  7              28
# 14           39             41                 -2              30
# 15           32             38                 -6              30
# 16           49             29                 20              30
# 17           41             54                -13              30
# 18           51             50                  1              30
# 19           40             32                  8              34
# 20           22             54                -32              28
# 21           43             36                  7              30
# 22           48             40                  8              30
# 23           53             38                 15              30
# 24           38             32                  6              30
# 25           35             40                 -5              30
# 26           48             53                 -5              34
# 27           45             40                  5              28
# 28           33             34                 -1              30
# 29           36             37                 -1              30
# 30           30             65                -35              30
# 31           21             45                -24              30
# 32           75             30                 45              34
# 33           62             20                 42              28
# 34           58             20                 38              30
# 35           61             26                 35              30
# 36           69             27                 42              30
# 37           51             30                 21              30
# 38           51             29                 22              30
# 39           67             42                 25              34
# 40           49             30                 19              28
# 41           59             42                 17              30
# 42           63             35                 28              30
# 43           33             40                 -7              30
# 44           11              6                  5               6
# 45           52             29                 23              30
# 46           56             29                 27              30
# 47           31             57                -26              34
# 48           50             55                 -5              30
# 49           48             53                 -5              30
# 50           44             58                -14              34
# 51           66             26                 40              34
# 52           38             34                  4              28
# 53           50             38                 12              30
# 54           43             33                 10              30
# 55           54             33                 21              30
# 56           49             39                 10              30
# 57           41             51                -10              30
# 58           46             52                 -6              34
# 59           36             46                -10              28
# 60           34             30                  4              30
# 61           40             50                -10              30
# 62           44             42                  2              30
# 63           37             39                 -2              30
# 64           48             50                 -2              30
# 65           59             50                  9              34
# 66           52             33                 19              28
# 67           60             35                 25              30
# 68           51             32                 19              30
# 69           66             43                 23              30
# 70           69             28                 41              30
# 71           64             30                 34              30
# 72           33             59                -26              34
# 73           29             58                -29              28
# 74           37             55                -18              34
# ...         ...            ...                ...             ...
# 1425         67             43                 24              36
# 1426         50             56                 -6              36
# 1427         65             56                  9              36
# 1428         44             51                 -7              36
# 1429         42             92                -50              36
# 1430         42             75                -33              36
# 1431         85             46                 39              36
# 1432         78             47                 31              36
# 1433         65             50                 15              36
# 1434         52             38                 14              34
# 1435         48             50                 -2              36
# 1436         59             50                  9              36
# 1437         64             45                 19              36
# 1438         78             47                 31              36
# 1439         72             44                 28              36
# 1440         90             46                 44              36
# 1441         76             44                 32              36
# 1442         78             33                 45              34
# 1443         61             31                 30              36
# 1444         70             34                 36              36
# 1445         84             41                 43              36
# 1446         88             38                 50              36
# 1447         35             51                -16              36
# 1448         32             88                -56              36
# 1449         55             71                -16              36
# 1450         31             64                -33              36
# 1451         44             60                -16              36
# 1452         63             57                  6              36
# 1453         47             36                 11              36
# 1454         40             35                  5              34
# 1455         40             54                -14              36
# 1456         38             45                 -7              36
# 1457         47             48                 -1              36
# 1458         52             49                  3              36
# 1459         45             62                -17              36
# 1460         66             55                 11              36
# 1461         62             57                  5              36
# 1462         46             32                 14              34
# 1463         41             52                -11              36
# 1464         48             54                 -6              36
# 1465         54             46                  8              36
# 1466         59             50                  9              36
# 1467         28             85                -57              36
# 1468         28             59                -31              36
# 1469         44             60                -16              36
# 1470         50             57                 -7              36
# 1471         55             57                 -2              36
# 1472         44             67                -23              36
# 1473         22             22                  0              18
# 1474         80             36                 44              36
# 1475         55             58                 -3              36
# 1476         74             44                 30              36
# 1477         43             44                 -1              34
# 1478         62             48                 14              36
# 1479         51             52                 -1              36
# 1480         55             48                  7              36
# 1481         48             71                -23              36
# 1482         53             56                 -3              36
# 1483         34             67                -33              36
# 1484         54             36                 18              36
# 1485         37             47                -10              36
# 1486         57             65                 -8              36
# 1487         41             66                -25              36
# 1488         48             43                  5              36
# 1489         38             41                 -3              34
# 1490         44             46                 -2              36
# 1491         57             53                  4              36
# 1492         47             45                  2              36
# 1493         45             54                 -9              36
# 1494         45             53                 -8              34
# 1495         32             62                -30              36
# 1496         29             61                -32              34
# 1497         32             51                -19              36
# 1498         38             71                -33              36
# 1499         46             75                -29              36
#
#       Home_Away_Diff                    League
# 0                  7    Belgium Jupiler League
# 1                  4    Belgium Jupiler League
# 2                  7    Belgium Jupiler League
# 3                 34    Belgium Jupiler League
# 4                 13    Belgium Jupiler League
# 5                 16    Belgium Jupiler League
# 6                 20    Belgium Jupiler League
# 7                 24    Belgium Jupiler League
# 8                  9    Belgium Jupiler League
# 9                 24    Belgium Jupiler League
# 10                32    Belgium Jupiler League
# 11                 2    Belgium Jupiler League
# 12                13    Belgium Jupiler League
# 13                13    Belgium Jupiler League
# 14                10    Belgium Jupiler League
# 15                14    Belgium Jupiler League
# 16                -4    Belgium Jupiler League
# 17                -5    Belgium Jupiler League
# 18                15    Belgium Jupiler League
# 19                10    Belgium Jupiler League
# 20                18    Belgium Jupiler League
# 21                 9    Belgium Jupiler League
# 22                 4    Belgium Jupiler League
# 23                -7    Belgium Jupiler League
# 24                12    Belgium Jupiler League
# 25                -1    Belgium Jupiler League
# 26                17    Belgium Jupiler League
# 27                11    Belgium Jupiler League
# 28                11    Belgium Jupiler League
# 29                11    Belgium Jupiler League
# 30                13    Belgium Jupiler League
# 31                 2    Belgium Jupiler League
# 32                21    Belgium Jupiler League
# 33                -8    Belgium Jupiler League
# 34                26    Belgium Jupiler League
# 35                27    Belgium Jupiler League
# 36                 8    Belgium Jupiler League
# 37                 7    Belgium Jupiler League
# 38                10    Belgium Jupiler League
# 39                 7    Belgium Jupiler League
# 40                -3    Belgium Jupiler League
# 41                 7    Belgium Jupiler League
# 42                18    Belgium Jupiler League
# 43                 7    Belgium Jupiler League
# 44                 3    Belgium Jupiler League
# 45                 9    Belgium Jupiler League
# 46                15    Belgium Jupiler League
# 47                22    Belgium Jupiler League
# 48                23    Belgium Jupiler League
# 49                -5    Belgium Jupiler League
# 50                10    Belgium Jupiler League
# 51                20    Belgium Jupiler League
# 52                 4    Belgium Jupiler League
# 53                24    Belgium Jupiler League
# 54                28    Belgium Jupiler League
# 55                 5    Belgium Jupiler League
# 56                 4    Belgium Jupiler League
# 57                22    Belgium Jupiler League
# 58                14    Belgium Jupiler League
# 59                16    Belgium Jupiler League
# 60                24    Belgium Jupiler League
# 61                14    Belgium Jupiler League
# 62                 0    Belgium Jupiler League
# 63                22    Belgium Jupiler League
# 64                18    Belgium Jupiler League
# 65                19    Belgium Jupiler League
# 66                 5    Belgium Jupiler League
# 67                13    Belgium Jupiler League
# 68                21    Belgium Jupiler League
# 69                 9    Belgium Jupiler League
# 70                11    Belgium Jupiler League
# 71                32    Belgium Jupiler League
# 72                18    Belgium Jupiler League
# 73                 1    Belgium Jupiler League
# 74                12    Belgium Jupiler League
# ...              ...                       ...
# 1425               2  Switzerland Super League
# 1426              12  Switzerland Super League
# 1427              19  Switzerland Super League
# 1428              19  Switzerland Super League
# 1429              18  Switzerland Super League
# 1430               7  Switzerland Super League
# 1431              27  Switzerland Super League
# 1432              25  Switzerland Super League
# 1433               9  Switzerland Super League
# 1434               8  Switzerland Super League
# 1435              32  Switzerland Super League
# 1436               5  Switzerland Super League
# 1437              23  Switzerland Super League
# 1438              21  Switzerland Super League
# 1439              20  Switzerland Super League
# 1440              28  Switzerland Super League
# 1441              14  Switzerland Super League
# 1442              13  Switzerland Super League
# 1443              22  Switzerland Super League
# 1444              10  Switzerland Super League
# 1445              13  Switzerland Super League
# 1446               8  Switzerland Super League
# 1447              26  Switzerland Super League
# 1448              10  Switzerland Super League
# 1449              18  Switzerland Super League
# 1450               7  Switzerland Super League
# 1451               8  Switzerland Super League
# 1452              38  Switzerland Super League
# 1453               7  Switzerland Super League
# 1454              -7  Switzerland Super League
# 1455              10  Switzerland Super League
# 1456              29  Switzerland Super League
# 1457              17  Switzerland Super League
# 1458              19  Switzerland Super League
# 1459              23  Switzerland Super League
# 1460              35  Switzerland Super League
# 1461               9  Switzerland Super League
# 1462              10  Switzerland Super League
# 1463               9  Switzerland Super League
# 1464              14  Switzerland Super League
# 1465               4  Switzerland Super League
# 1466              17  Switzerland Super League
# 1467              25  Switzerland Super League
# 1468              -1  Switzerland Super League
# 1469              16  Switzerland Super League
# 1470              21  Switzerland Super League
# 1471              18  Switzerland Super League
# 1472              -1  Switzerland Super League
# 1473               4  Switzerland Super League
# 1474               2  Switzerland Super League
# 1475              25  Switzerland Super League
# 1476              10  Switzerland Super League
# 1477               5  Switzerland Super League
# 1478               6  Switzerland Super League
# 1479               9  Switzerland Super League
# 1480              -3  Switzerland Super League
# 1481              17  Switzerland Super League
# 1482               5  Switzerland Super League
# 1483              -3  Switzerland Super League
# 1484              18  Switzerland Super League
# 1485              18  Switzerland Super League
# 1486              24  Switzerland Super League
# 1487              11  Switzerland Super League
# 1488               1  Switzerland Super League
# 1489              15  Switzerland Super League
# 1490              16  Switzerland Super League
# 1491              12  Switzerland Super League
# 1492              26  Switzerland Super League
# 1493               7  Switzerland Super League
# 1494               0  Switzerland Super League
# 1495              22  Switzerland Super League
# 1496              24  Switzerland Super League
# 1497              21  Switzerland Super League
# 1498               3  Switzerland Super League
# 1499              17  Switzerland Super League
#
# [1500 rows x 11 columns]

# %%
temp.team_df.columns
# Out:
# Index(['id', 'team_api_id', 'team_fifa_api_id', 'team_long_name',
#        'team_short_name'],
#       dtype='object')

# %%
temp.league_df
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
temp.match_df[["league_id", "home_team_api_id"]].drop_duplicates()
# Out:
#        league_id  home_team_api_id
# 0              1              9987
# 1              1             10000
# 2              1              9984
# 3              1              9991
# 4              1              7947
# 5              1              8203
# 6              1              9999
# 7              1              4049
# 8              1             10001
# 9              1              8342
# 10             1              9985
# 12             1              9994
# 15             1              9996
# 17             1              9993
# 18             1              8635
# 19             1              9998
# 20             1              9986
# 24             1              8571
# 315            1              9997
# 531            1              9989
# 537            1              6351
# 756            1              1773
# 1011           1              8475
# 1239           1              8573
# 1259           1            274581
# 1728        1729             10260
# 1729        1729              9825
# 1730        1729              8472
# 1731        1729              8654
# 1732        1729             10252
# 1733        1729              8668
# 1734        1729              8549
# 1735        1729              8559
# 1736        1729              8667
# 1737        1729              8455
# 1743        1729             10194
# 1744        1729              8650
# 1746        1729             10261
# 1747        1729              9879
# 1749        1729              8586
# 1754        1729              8659
# 1755        1729              8462
# 1763        1729              8456
# 1764        1729              8655
# 1767        1729              8528
# 2112        1729              8602
# 2118        1729              8191
# 2121        1729              8658
# 2507        1729              8483
# 2873        1729             10172
# 2881        1729              9850
# 2884        1729             10003
# 3254        1729              9798
# 3275        1729              8466
# 3630        1729              9826
# 3639        1729              8344
# 4010        1729              8197
# 4389        1729              8678
# 4416        1729              9817
# 4768        4769              8583
# 4769        4769              9827
# 4770        4769              9746
# 4771        4769              8682
# 4772        4769              9748
# 4773        4769              9829
# 4774        4769              8481
# 4775        4769              9851
# 4776        4769              9874
# 4777        4769              9873
# 4780        4769              8639
# 4781        4769              8689
# 4782        4769              8592
# 4784        4769              9831
# 4786        4769              9853
# 4787        4769              9941
# ...          ...               ...
# 18136      17642              9765
# 18361      17642              4064
# 18367      17642              9764
# 18616      17642              8348
# 18620      17642              7842
# 18858      17642            158085
# 19086      17642              6547
# 19091      17642              8613
# 19394      17642              6367
# 19395      17642            188163
# 19693      19694              8596
# 19694      19694              9860
# 19695      19694              8597
# 19696      19694              8485
# 19697      19694              9925
# 19698      19694              8429
# 19700      19694              9938
# 19703      19694              8066
# 19705      19694              8548
# 19706      19694              9927
# 19709      19694              9800
# 19713      19694             10251
# 19926      19694              8467
# 20378      19694              8457
# 20608      19694              8649
# 20611      19694              8284
# 20836      19694              8426
# 21517      21518             10267
# 21518      21518              8371
# 21519      21518              9783
# 21520      21518              8388
# 21521      21518              8696
# 21522      21518              9869
# 21523      21518              8603
# 21524      21518              8558
# 21525      21518              8315
# 21526      21518              9906
# 21527      21518              8302
# 21532      21518             10205
# 21533      21518              8633
# 21534      21518              8634
# 21535      21518              8305
# 21536      21518              8661
# 21542      21518              9865
# 21543      21518              9864
# 21544      21518             10281
# 21546      21518              8479
# 21901      21518              8394
# 21907      21518              9867
# 21919      21518              9868
# 22278      21518             10278
# 22282      21518              8581
# 22284      21518              8560
# 22666      21518              8370
# 22676      21518              7878
# 23043      21518              9910
# 23429      21518             10268
# 23802      21518              8372
# 23818      21518              7869
# 24200      21518              8306
# 24557      24558              9956
# 24558      24558             10192
# 24559      24558              9930
# 24560      24558             10199
# 24561      24558              7955
# 24562      24558              6493
# 24563      24558              9931
# 24564      24558             10179
# 24565      24558              9824
# 24566      24558             10243
# 24739      24558             10190
# 24918      24558             10191
# 25100      24558              9777
# 25105      24558              7730
# 25815      24558              7896
#
# [299 rows x 2 columns]
