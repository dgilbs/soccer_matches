# %%
import pandas as pd
import pymysql
import sqlite3
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 150)

# %%
connection = sqlite3.connect("/Users/danielgilberg/data_science/metis/soccer_matches/database.sqlite")

# %%
connection

# %%
c = connection.cursor()

# %%
query = c.execute('''SELECT * FROM player LIMIT 10''')
query1 = '''SELECT * FROM match WHERE home_team_api_id =9825'''

# %%
df = pd.read_sql(query1, connection)
#df[["home_player_X9", "home_player_Y9", "away_player_X9", "away_player_Y9"]]
df
# Out:
#        id  country_id  league_id     season  stage                 date  \
# 0    1730        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 1    1740        1729       1729  2008/2009     10  2008-10-29 00:00:00
# 2    1759        1729       1729  2008/2009     12  2008-11-08 00:00:00
# 3    1770        1729       1729  2008/2009     13  2008-11-15 00:00:00
# 4    1800        1729       1729  2008/2009     16  2008-12-06 00:00:00
# 5    1820        1729       1729  2008/2009     18  2008-12-21 00:00:00
# 6    1850        1729       1729  2008/2009     20  2008-12-28 00:00:00
# 7    1860        1729       1729  2008/2009     21  2009-01-10 00:00:00
# 8    1890        1729       1729  2008/2009     24  2009-01-31 00:00:00
# 9    1910        1729       1729  2008/2009     26  2009-02-21 00:00:00
# 10   1920        1729       1729  2008/2009     27  2009-02-28 00:00:00
# 11   1940        1729       1729  2008/2009     29  2009-03-14 00:00:00
# ...

# %%
df.iloc[10]
# Out:
# id                                                               1920
# country_id                                                       1729
# league_id                                                        1729
# season                                                      2008/2009
# stage                                                              27
# date                                              2009-02-28 00:00:00
# match_api_id                                                   489304
# home_team_api_id                                                 9825
# away_team_api_id                                                 9879
# home_team_goal                                                      0
# away_team_goal                                                      0
# home_player_X1                                                      1
# home_player_X2                                                      2
# ...

# %%
df[df.id == 1920][["home_player_X6", "home_player_Y6"]]
# Out:
#     home_player_X6  home_player_Y6
# 10               1               7

# %%
team_query = '''SELECT * FROM team WHERE team_short_name = "ARS" '''
team = pd.read_sql(team_query, connection)
team
# Out:
#      id  team_api_id  team_fifa_api_id team_long_name team_short_name
# 0  3459         9825                 1        Arsenal             ARS

# %%
# Out:
#    id  team_api_id  team_fifa_api_id        team_long_name team_short_name
# 0  16         9996            111560  Royal Excel Mouscron             MOU

# %%
players = '''SELECT * FROM player LIMIT 10'''
pd.read_sql(players, connection)
players_query = '''SELECT * FROM player WHERE player_api_id = 3520'''
pd.read_sql(players_query,connection)
# Out:
#     id  player_api_id      player_name  player_fifa_api_id  \
# 0  769           3520  Andrey Arshavin              147777
#
#               birthday  height  weight
# 0  1981-05-29 00:00:00  172.72     154

# %%
test_df = df[df.id == 1920]
x_cords = list()
y_cords = list()
ids = list()
match = test_df.iloc[0]
for i in range(1,12):
    num = str(i)
    x_col = "away_player_X{}".format(num)
    y_col = "away_player_Y{}".format(num)
    id_col = "away_player_{}".format(num)
    x_cords.append(match[x_col])
    y_cords.append(match[y_col])
    ids.append(match[id_col])

# %%
x_cords
# Out:
# [1, 2, 4, 6, 8, 2, 4, 6, 8, 4, 6]

# %%
y_cords
# Out:
# [1, 3, 3, 3, 3, 7, 7, 7, 7, 10, 10]

# %%
ids
# Out:
# [23686, 26111, 30831, 38835, 31291, 3520, 39297, 27277, 26181, 75342, 30843]

# %%
ax = plt.scatter(y_cords, x_cords)
for index, player in enumerate(ids):
    print((x_cords[index], y_cords[index]))
    #ax.annotate(player, (x_cords[index], y_cords[index]))
# Out:
# (1, 1)
# (2, 3)
# (4, 3)
# (6, 3)
# (8, 3)
# (2, 7)
# (4, 7)
# (6, 7)
# (8, 7)
# (4, 10)
# (6, 10)

# %% [markdown]
# multi labeled output models
